# %% [markdown]
# ## Julio Cesar Mendez Torres

# %%
import pandas as pd

# %%
#DF de una url
url = 'https://es.wikipedia.org/wiki/Love_at_First_Sting'
df_html4 = pd.read_html(url)
print(type(df_html4))
df_html4
print("El numero de tablas en DF", len(df_html4))
# Out:
# <class 'list'>
# El numero de tablas en DF 14

# %%
df_html4
# Out:
# [                                  Love at First Sting  \
#  0                                                 NaN
#  1                       Álbum de estudio de Scorpions
#  2                                         Publicación
#  3                                           Grabación
#  4                                             Estudio
#  5                                           Género(s)
#  6                                            Duración
#  7                                        Discográfica
#  8                                       Productor(es)
#  9   Cronología de Scorpions Hot & Heavy (1982) Lov...
#  10                                 Hot & Heavy (1982)
#  11                                                NaN
#  12                   Sencillos de Love at First Sting
#  13  «Rock You Like a Hurricane» Publicado: 9 de fe...
#  14                         [editar datos en Wikidata]
#
#                                  Love at First Sting.1  \
# ...

# %%
from sqlalchemy import create_engine

us = 'fesalu'
passwd = 'bdfes2023'
url = 'bd.arcelia.net'
puerto = '3306'
bd = 'bdcolegio02'
auth = 'mysql_native_password'

str_conn = 'mysql+mysqlconnector://{0}:{1}@{2}:{3}/{4}?auth_plugin={5}'
str_conn = str_conn.format(us, passwd, url, puerto, bd, auth)

# %%
conn = create_engine(str_conn)
conn
# Out:
# Engine(mysql+mysqlconnector://fesalu:***@bd.arcelia.net:3306/bdcolegio02?auth_plugin=mysql_native_password)

# %%
#sql = '''SELECT * FROM alumnos'''

#df_mysql = pd.read_sql_query(sql=sql, con=conn)

#sql = '''SELECT * FROM alumnos WHERE DATE(fedita) >=  %s'''

#df_mysql = pd.read_sql_query(sql=sql, con=conn, params=[('2021-01-01 00:00:00',)])

sql = '''SELECT * FROM alumnos WHERE sexo =  %s'''

df_mysql = pd.read_sql_query(sql=sql, con=conn, params=[('F',)])

# %%
df_mysql
# Out:
#     clave_alu clave_admin ap_paterno ap_materno             nombre sexo  \
# 0    11030172        4812   BORBOLLA      RAMOS            ARGELIA    F
# 1    11030173        4849     CASTRO    MANCERA      KARLA MARIANA    F
# 2    11030207        4808    AGUILAR  ZAMARRIPA    MICHELLE IVONNE    F
# 3    11030218        4717     FLORES      NAMUR     MARIA FERNANDA    F
# 4    11030254        4724   GONZALEZ       DIAZ  CLAUDIA ALEJANDRA    F
# ..        ...         ...        ...        ...                ...  ...
# 278  11080201                   SOTO      ELIAS     PALOMA DENISSE    F
# 279  11080202                 VALLES      RAMOS            MARIANA    F
# 280  11080205                  BADUY     VALDEZ      KENNIA ASENET    F
# 281  11080208               BECERRIL     HUERTA            MARIANA    F
# 282  11080209        NULL    MORALES    CARMONA      KARLA MARIANA    F
#
#                    curp  peso  estatura                           direccion  \
# ...
